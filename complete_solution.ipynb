# %%
from datetime import date
from nsepy import get_history

# %%
sbin= get_history(symbol="SBIN",start=date(2015,1,1) ,end= date(2015,1,31))

# %%
sbin.head()
# Out:
#            Symbol Series  Prev Close    Open    High     Low   Last   Close  \
# Date
# 2015-01-01   SBIN     EQ      311.85  312.45  315.00  310.70  314.0  314.00
# 2015-01-02   SBIN     EQ      314.00  314.35  318.30  314.35  315.6  315.25
# 2015-01-05   SBIN     EQ      315.25  316.25  316.80  312.10  312.8  312.75
# 2015-01-06   SBIN     EQ      312.75  310.00  311.10  298.70  299.9  299.90
# 2015-01-07   SBIN     EQ      299.90  300.00  302.55  295.15  301.4  300.15
#
#               VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2015-01-01  313.67   6138488  1.925489e+14   58688             1877677
# 2015-01-02  316.80   9935094  3.147389e+14   79553             4221685
# 2015-01-05  313.84   9136716  2.867432e+14   88236             3845173
# 2015-01-06  305.14  15329257  4.677601e+14  169268             7424847
# 2015-01-07  299.95  15046745  4.513243e+14  147185             5631400
#
#             %Deliverble
# Date
# 2015-01-01       0.3059
# ...

# %% [markdown]
# PART-1 (1)

# %% [markdown]
# PART-1 (2)

# %%
sbin.rolling(10)
# Out:
# Rolling [window=10,center=False,axis=0]

# %%
sbin
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2015-01-01   SBIN     EQ      311.85  312.45  315.00  310.70  314.00  314.00
# 2015-01-02   SBIN     EQ      314.00  314.35  318.30  314.35  315.60  315.25
# 2015-01-05   SBIN     EQ      315.25  316.25  316.80  312.10  312.80  312.75
# 2015-01-06   SBIN     EQ      312.75  310.00  311.10  298.70  299.90  299.90
# 2015-01-07   SBIN     EQ      299.90  300.00  302.55  295.15  301.40  300.15
# 2015-01-08   SBIN     EQ      300.15  305.00  306.50  302.35  305.25  304.85
# 2015-01-09   SBIN     EQ      304.85  306.70  307.85  302.00  303.00  303.20
# 2015-01-12   SBIN     EQ      303.20  304.15  307.80  301.10  306.90  307.10
# 2015-01-13   SBIN     EQ      307.10  308.15  310.75  304.15  305.25  305.10
# 2015-01-14   SBIN     EQ      305.10  304.00  307.00  302.25  305.00  304.70
# 2015-01-15   SBIN     EQ      304.70  319.90  323.70  314.00  318.40  320.30
# ...

# %%
sbin.rolling(20)
# Out:
# Rolling [window=20,center=False,axis=0]

# %%
sbin
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2015-01-01   SBIN     EQ      311.85  312.45  315.00  310.70  314.00  314.00
# 2015-01-02   SBIN     EQ      314.00  314.35  318.30  314.35  315.60  315.25
# 2015-01-05   SBIN     EQ      315.25  316.25  316.80  312.10  312.80  312.75
# 2015-01-06   SBIN     EQ      312.75  310.00  311.10  298.70  299.90  299.90
# 2015-01-07   SBIN     EQ      299.90  300.00  302.55  295.15  301.40  300.15
# 2015-01-08   SBIN     EQ      300.15  305.00  306.50  302.35  305.25  304.85
# 2015-01-09   SBIN     EQ      304.85  306.70  307.85  302.00  303.00  303.20
# 2015-01-12   SBIN     EQ      303.20  304.15  307.80  301.10  306.90  307.10
# 2015-01-13   SBIN     EQ      307.10  308.15  310.75  304.15  305.25  305.10
# 2015-01-14   SBIN     EQ      305.10  304.00  307.00  302.25  305.00  304.70
# 2015-01-15   SBIN     EQ      304.70  319.90  323.70  314.00  318.40  320.30
# ...

# %%
sbin.rolling(30)
# Out:
# Rolling [window=30,center=False,axis=0]

# %%
sbin
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2015-01-01   SBIN     EQ      311.85  312.45  315.00  310.70  314.00  314.00
# 2015-01-02   SBIN     EQ      314.00  314.35  318.30  314.35  315.60  315.25
# 2015-01-05   SBIN     EQ      315.25  316.25  316.80  312.10  312.80  312.75
# 2015-01-06   SBIN     EQ      312.75  310.00  311.10  298.70  299.90  299.90
# 2015-01-07   SBIN     EQ      299.90  300.00  302.55  295.15  301.40  300.15
# 2015-01-08   SBIN     EQ      300.15  305.00  306.50  302.35  305.25  304.85
# 2015-01-09   SBIN     EQ      304.85  306.70  307.85  302.00  303.00  303.20
# 2015-01-12   SBIN     EQ      303.20  304.15  307.80  301.10  306.90  307.10
# 2015-01-13   SBIN     EQ      307.10  308.15  310.75  304.15  305.25  305.10
# 2015-01-14   SBIN     EQ      305.10  304.00  307.00  302.25  305.00  304.70
# 2015-01-15   SBIN     EQ      304.70  319.90  323.70  314.00  318.40  320.30
# ...

# %%
sbin.rolling(40)
# Out:
# Rolling [window=40,center=False,axis=0]

# %%
sbin
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2015-01-01   SBIN     EQ      311.85  312.45  315.00  310.70  314.00  314.00
# 2015-01-02   SBIN     EQ      314.00  314.35  318.30  314.35  315.60  315.25
# 2015-01-05   SBIN     EQ      315.25  316.25  316.80  312.10  312.80  312.75
# 2015-01-06   SBIN     EQ      312.75  310.00  311.10  298.70  299.90  299.90
# 2015-01-07   SBIN     EQ      299.90  300.00  302.55  295.15  301.40  300.15
# 2015-01-08   SBIN     EQ      300.15  305.00  306.50  302.35  305.25  304.85
# 2015-01-09   SBIN     EQ      304.85  306.70  307.85  302.00  303.00  303.20
# 2015-01-12   SBIN     EQ      303.20  304.15  307.80  301.10  306.90  307.10
# 2015-01-13   SBIN     EQ      307.10  308.15  310.75  304.15  305.25  305.10
# 2015-01-14   SBIN     EQ      305.10  304.00  307.00  302.25  305.00  304.70
# 2015-01-15   SBIN     EQ      304.70  319.90  323.70  314.00  318.40  320.30
# ...

# %%
sbin.rolling(75)
# Out:
# Rolling [window=75,center=False,axis=0]

# %%
sbin
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2015-01-01   SBIN     EQ      311.85  312.45  315.00  310.70  314.00  314.00
# 2015-01-02   SBIN     EQ      314.00  314.35  318.30  314.35  315.60  315.25
# 2015-01-05   SBIN     EQ      315.25  316.25  316.80  312.10  312.80  312.75
# 2015-01-06   SBIN     EQ      312.75  310.00  311.10  298.70  299.90  299.90
# 2015-01-07   SBIN     EQ      299.90  300.00  302.55  295.15  301.40  300.15
# 2015-01-08   SBIN     EQ      300.15  305.00  306.50  302.35  305.25  304.85
# 2015-01-09   SBIN     EQ      304.85  306.70  307.85  302.00  303.00  303.20
# 2015-01-12   SBIN     EQ      303.20  304.15  307.80  301.10  306.90  307.10
# 2015-01-13   SBIN     EQ      307.10  308.15  310.75  304.15  305.25  305.10
# 2015-01-14   SBIN     EQ      305.10  304.00  307.00  302.25  305.00  304.70
# 2015-01-15   SBIN     EQ      304.70  319.90  323.70  314.00  318.40  320.30
# ...

# %% [markdown]
# PART-1 (3)

# %%
import numpy as np
for j in range(len(sbin)):
    if int(sbin.iloc[j]['Volume'])>=int(1.1*sbin.iloc[j-1]['Volume']):       
        sbin['volume_shocks']=0
    else:
        sbin['volume_shocks']=1

# %%
sbin
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2015-01-01   SBIN     EQ      311.85  312.45  315.00  310.70  314.00  314.00
# 2015-01-02   SBIN     EQ      314.00  314.35  318.30  314.35  315.60  315.25
# 2015-01-05   SBIN     EQ      315.25  316.25  316.80  312.10  312.80  312.75
# 2015-01-06   SBIN     EQ      312.75  310.00  311.10  298.70  299.90  299.90
# 2015-01-07   SBIN     EQ      299.90  300.00  302.55  295.15  301.40  300.15
# 2015-01-08   SBIN     EQ      300.15  305.00  306.50  302.35  305.25  304.85
# 2015-01-09   SBIN     EQ      304.85  306.70  307.85  302.00  303.00  303.20
# 2015-01-12   SBIN     EQ      303.20  304.15  307.80  301.10  306.90  307.10
# 2015-01-13   SBIN     EQ      307.10  308.15  310.75  304.15  305.25  305.10
# 2015-01-14   SBIN     EQ      305.10  304.00  307.00  302.25  305.00  304.70
# 2015-01-15   SBIN     EQ      304.70  319.90  323.70  314.00  318.40  320.30
# ...

# %%
for t in range(len(sbin)):
    if (abs(int(sbin.iloc[t]['Close'])-int(sbin.iloc[t-1]['Close']))>0.02*sbin.iloc[t]['Close']):       
        sbin['price_shocks']=0
    else:
        sbin['price_shocks']=1
        
    #print((abs(int(sbin.iloc[t]['Close'])-int(sbin.iloc[t-1]['Close'])),0.02*sbin.iloc[t]['Close']))
# Out:
# (6, 6.28)
# (1, 6.305)
# (3, 6.255)
# (13, 5.997999999999999)
# (1, 6.003)
# (4, 6.097)
# (1, 6.064)
# (4, 6.142)
# (2, 6.102)
# (1, 6.094)
# (16, 6.406000000000001)
# (5, 6.309)
# (2, 6.263)
# (5, 6.3629999999999995)
# (8, 6.524)
# (2, 6.492999999999999)
# (3, 6.5489999999999995)
# (3, 6.601)
# (4, 6.692)
# (7, 6.54)
# (19, 6.179)

# %%
sbin
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2015-01-01   SBIN     EQ      311.85  312.45  315.00  310.70  314.00  314.00
# 2015-01-02   SBIN     EQ      314.00  314.35  318.30  314.35  315.60  315.25
# 2015-01-05   SBIN     EQ      315.25  316.25  316.80  312.10  312.80  312.75
# 2015-01-06   SBIN     EQ      312.75  310.00  311.10  298.70  299.90  299.90
# 2015-01-07   SBIN     EQ      299.90  300.00  302.55  295.15  301.40  300.15
# 2015-01-08   SBIN     EQ      300.15  305.00  306.50  302.35  305.25  304.85
# 2015-01-09   SBIN     EQ      304.85  306.70  307.85  302.00  303.00  303.20
# 2015-01-12   SBIN     EQ      303.20  304.15  307.80  301.10  306.90  307.10
# 2015-01-13   SBIN     EQ      307.10  308.15  310.75  304.15  305.25  305.10
# 2015-01-14   SBIN     EQ      305.10  304.00  307.00  302.25  305.00  304.70
# 2015-01-15   SBIN     EQ      304.70  319.90  323.70  314.00  318.40  320.30
# ...

# %%
for r in range(len(sbin)):
    if ((int(sbin.iloc[j]['Volume'])<=int(0.9*sbin.iloc[j-1]['Volume'])) & (abs(int(sbin.iloc[t]['Close'])-int(sbin.iloc[t-1]['Close']))>0.02*sbin.iloc[t]['Close'])):       
        sbin['pswvs']=1
    else:
        sbin['pswvs']=0

# %%
sbin
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2015-01-01   SBIN     EQ      311.85  312.45  315.00  310.70  314.00  314.00
# 2015-01-02   SBIN     EQ      314.00  314.35  318.30  314.35  315.60  315.25
# 2015-01-05   SBIN     EQ      315.25  316.25  316.80  312.10  312.80  312.75
# 2015-01-06   SBIN     EQ      312.75  310.00  311.10  298.70  299.90  299.90
# 2015-01-07   SBIN     EQ      299.90  300.00  302.55  295.15  301.40  300.15
# 2015-01-08   SBIN     EQ      300.15  305.00  306.50  302.35  305.25  304.85
# 2015-01-09   SBIN     EQ      304.85  306.70  307.85  302.00  303.00  303.20
# 2015-01-12   SBIN     EQ      303.20  304.15  307.80  301.10  306.90  307.10
# 2015-01-13   SBIN     EQ      307.10  308.15  310.75  304.15  305.25  305.10
# 2015-01-14   SBIN     EQ      305.10  304.00  307.00  302.25  305.00  304.70
# 2015-01-15   SBIN     EQ      304.70  319.90  323.70  314.00  318.40  320.30
# ...

# %% [markdown]
# PART-2 (1)

# %%
import matplotlib.pyplot as plt
close= sbin[['Close']]
close.plot(figsize=(20,10), linewidth=5, fontsize=20,color='purple')
plt.xlabel('Closing price', fontsize=20);
plt.show()

# %% [markdown]
# PART-2 (2)

# %%
sbin.plot(figsize=(20,10), linewidth=5, fontsize=20,color='blue')
plt.xlabel('timeseries', fontsize=20);
plt.show()

# %% [markdown]
# PART-2 (3)

# %%
vs=sbin[['volume_shocks']]
vs.plot(figsize=(20,10), linewidth=5, fontsize=20,color="red")
plt.xlabel('volume_shocks', fontsize=20);
plt.show()

# %% [markdown]
# PART-3

# %%
sbi= get_history(symbol="SBIN",start=date(2015,1,1),end=date(2015,12,31))

# %%
sbi
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2015-01-01   SBIN     EQ      311.85  312.45  315.00  310.70  314.00  314.00
# 2015-01-02   SBIN     EQ      314.00  314.35  318.30  314.35  315.60  315.25
# 2015-01-05   SBIN     EQ      315.25  316.25  316.80  312.10  312.80  312.75
# 2015-01-06   SBIN     EQ      312.75  310.00  311.10  298.70  299.90  299.90
# 2015-01-07   SBIN     EQ      299.90  300.00  302.55  295.15  301.40  300.15
# 2015-01-08   SBIN     EQ      300.15  305.00  306.50  302.35  305.25  304.85
# 2015-01-09   SBIN     EQ      304.85  306.70  307.85  302.00  303.00  303.20
# 2015-01-12   SBIN     EQ      303.20  304.15  307.80  301.10  306.90  307.10
# 2015-01-13   SBIN     EQ      307.10  308.15  310.75  304.15  305.25  305.10
# 2015-01-14   SBIN     EQ      305.10  304.00  307.00  302.25  305.00  304.70
# 2015-01-15   SBIN     EQ      304.70  319.90  323.70  314.00  318.40  320.30
# ...

# %%
from sklearn.linear_model import LinearRegression
x=sbi.drop(['Close','Series','Symbol'],axis=1)
y=sbi['Close']
# Out:
#             Prev Close    Open    High     Low    Last    VWAP    Volume  \
# Date
# 2015-01-01      311.85  312.45  315.00  310.70  314.00  313.67   6138488
# 2015-01-02      314.00  314.35  318.30  314.35  315.60  316.80   9935094
# 2015-01-05      315.25  316.25  316.80  312.10  312.80  313.84   9136716
# 2015-01-06      312.75  310.00  311.10  298.70  299.90  305.14  15329257
# 2015-01-07      299.90  300.00  302.55  295.15  301.40  299.95  15046745
# 2015-01-08      300.15  305.00  306.50  302.35  305.25  304.55   8939749
# 2015-01-09      304.85  306.70  307.85  302.00  303.00  304.45  11953948
# 2015-01-12      303.20  304.15  307.80  301.10  306.90  305.86   8536142
# 2015-01-13      307.10  308.15  310.75  304.15  305.25  308.22   9484804
# 2015-01-14      305.10  304.00  307.00  302.25  305.00  304.80   8855660
# 2015-01-15      304.70  319.90  323.70  314.00  318.40  318.25  30729523
# 2015-01-16      320.30  320.00  320.30  313.10  315.25  315.40  21598514
# ...

# %%
from sklearn.cross_validation import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.30)
clf= LinearRegression()
clf.fit(x_train,y_train)
y_pred= clf.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9995501654581842

# %%
from sklearn.linear_model import Ridge
clf2= Ridge()
clf2.fit(x_train,y_train)
y_pred2= clf2.predict(x_test)
r2_score(y_test,y_pred2)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.215638e-31
#   overwrite_a=True).T
# 0.9995532681252182
